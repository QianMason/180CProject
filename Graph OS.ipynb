# %%
import matplotlib.pyplot as plt
import numpy as np



with open("C:/Users/ashri/Desktop/os graphs/fcfs.csv") as inf:
        list1= [int(i) for i in inf.read().split(',')]

l=len(list1)    
list2 = []
for i in range(l):
    list2.append(i)

# %%
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = True
ax=plt.gca()
ax.invert_yaxis()
plt.xticks(np.arange(0, max(list1)+1, 10))
plt.yticks(np.arange(0, max(list1)+1, 10))
plt.plot(list1,list2,'r-',list1,list2,'bo')
plt.title("FCFS")
plt.show()

# %%
with open("C:/Users/ashri/Desktop/os graphs/sstf.csv") as inf:
        list1= [int(i) for i in inf.read().split(',')]

l=len(list1)    
list2 = []
for i in range(l):
    list2.append(i)
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = True
ax=plt.gca()
ax.invert_yaxis()
plt.xticks(np.arange(0, max(list1)+1, 10))
plt.yticks(np.arange(0, max(list1)+1, 10))
plt.plot(list1,list2,'r-',list1,list2,'bo')
plt.title("SSTF")
plt.show()

# %%
with open("C:/Users/ashri/Desktop/os graphs/scan.csv") as inf:
        list1= [int(i) for i in inf.read().split(',')]

l=len(list1)    
list2 = []
for i in range(l):
    list2.append(i)
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = True
ax=plt.gca()
ax.invert_yaxis()
plt.xticks(np.arange(0, max(list1)+1, 10))
plt.yticks(np.arange(0, max(list1)+1, 10))
plt.plot(list1,list2,'r-',list1,list2,'bo')
plt.title("SCAN")
plt.show()

# %%
with open("C:/Users/ashri/Desktop/os graphs/cscan.csv") as inf:
        list1= [int(i) for i in inf.read().split(',')]

l=len(list1)    
list2 = []
for i in range(l):
    list2.append(i)
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = True
ax=plt.gca()
ax.invert_yaxis()
plt.xticks(np.arange(0, max(list1)+1, 10))
plt.yticks(np.arange(0, max(list1)+1, 10))
plt.plot(list1,list2,'r-',list1,list2,'bo')
plt.title("CSCAN")
plt.show()

# %%
with open("C:/Users/ashri/Desktop/os graphs/look.csv") as inf:
        list1= [int(i) for i in inf.read().split(',')]

l=len(list1)    
list2 = []
for i in range(l):
    list2.append(i)
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = True
ax=plt.gca()
ax.invert_yaxis()
plt.xticks(np.arange(0, max(list1)+1, 10))
plt.yticks(np.arange(0, max(list1)+1, 10))
plt.plot(list1,list2,'r-',list1,list2,'bo')
plt.title("LOOK")
plt.show()

# %%
with open("C:/Users/ashri/Desktop/os graphs/clook.csv") as inf:
        list1= [int(i) for i in inf.read().split(',')]

l=len(list1)    
list2 = []
for i in range(l):
    list2.append(i)
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = True
ax=plt.gca()
ax.invert_yaxis()
plt.xticks(np.arange(0, max(list1)+1, 10))
plt.yticks(np.arange(0, max(list1)+1, 10))
plt.plot(list1,list2,'r-',list1,list2,'bo')
plt.title("CLOOK")
plt.show()
